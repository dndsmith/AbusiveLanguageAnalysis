# %%
import csv
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
# %matplotlib inline
# from sklearn.linear_model import LogisticRegression
# from sklearn.model_selection import GridSearchCV
# from sklearn.model_selection import RepeatedStratifiedKFold
# import sklearn
import re

# %% [markdown]
# ### Read in files
# #### Make sure current working directory is AbusiveLanguageAnalysis

# %%
df_comments = pd.read_csv('./data/aggression_annotated_comments.tsv', sep='\t')
df_annotations = pd.read_csv('./data/aggression_annotations.tsv', sep='\t')

# %% [markdown]
# ## Bunch of EDA
# #### Change the threshold of what constitutes an aggresion

# %%
threshold = 0.5

# %%
df_comments.head()
# Out:
#    rev_id                                            comment  year  logged_in  \
# 0   37675  `-NEWLINE_TOKENThis is not ``creative``.  Thos...  2002       True
# 1   44816  `NEWLINE_TOKENNEWLINE_TOKEN:: the term ``stand...  2002       True
# 2   49851  NEWLINE_TOKENNEWLINE_TOKENTrue or false, the s...  2002       True
# 3   89320   Next, maybe you could work on being less cond...  2002       True
# 4   93890               This page will need disambiguation.   2002       True
#
#         ns  sample  split
# 0  article  random  train
# 1  article  random  train
# 2  article  random  train
# 3  article  random    dev
# 4  article  random  train

# %%
df_annotations.head()
# Out:
#    rev_id  worker_id  aggression  aggression_score
# 0   37675       1362         1.0              -1.0
# 1   37675       2408         0.0               1.0
# 2   37675       1493         0.0               0.0
# 3   37675       1439         0.0               0.0
# 4   37675        170         0.0               0.0

# %% [markdown]
# ### Join the annotations with the comments to get both the text ('comment' column) and the outcome ('aggression' column)
# Also, assign whether or not a comment is aggressive

# %%
df = df_comments.join(df.groupby('rev_id')['aggression'].agg('mean').to_frame().reset_index().set_index('rev_id'), on='rev_id')
df.aggression = df.aggression.apply(lambda x: 1 if x > threshold else 0)
df
# Out:
#            rev_id                                            comment  year  \
# 0           37675  `-NEWLINE_TOKENThis is not ``creative``.  Thos...  2002
# 1           44816  `NEWLINE_TOKENNEWLINE_TOKEN:: the term ``stand...  2002
# 2           49851  NEWLINE_TOKENNEWLINE_TOKENTrue or false, the s...  2002
# 3           89320   Next, maybe you could work on being less cond...  2002
# 4           93890               This page will need disambiguation.   2002
# 5          102817  NEWLINE_TOKEN-NEWLINE_TOKENNEWLINE_TOKENImport...  2002
# 6          103624  I removed the following:NEWLINE_TOKENNEWLINE_T...  2002
# 7          111032  `:If you ever claimed in a Judaic studies prog...  2002
# 8          120283  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENMy apol...  2002
# 9          128532  `Someone wrote:NEWLINE_TOKENMore recognizable,...  2002
# 10         133562  NEWLINE_TOKENNEWLINE_TOKEN:Correct. Full biogr...  2002
# 11         138117  `NEWLINE_TOKENNEWLINE_TOKENCare should be take...  2002
# 12         155243  NEWLINE_TOKENNEWLINE_TOKEN:If I may butt in  I...  2002
# 13         177310  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENOn my  ...  2002
# 14         192579  `NEWLINE_TOKENNEWLINE_TOKEN:<>>NEWLINE_TOKENNE...  2002
# 15         201190        gets far more tendentious yet.NEWLINE_TOKEN  2002
# 16         208009  `NEWLINE_TOKENNEWLINE_TOKENAs a person who has...  2002
# 17         249432  It's great that we've found a new source of fr...  2001
# 18         252031  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2001
# 19         268558  NEWLINE_TOKENNEWLINE_TOKENI'd like the concept...  2001
# 20         276906  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2001
# 21         286174  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2002
# 22         290598  `NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLIN...  2001
# 23         294124  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2002
# 24         297866  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2001
# 25         317177   See? I was right! ;-)  NEWLINE_TOKENNEWLINE_T...  2002
# 26         336654  NEWLINE_TOKENNEWLINE_TOKEN:I have checked the ...  2002
# 27         344567  `NEWLINE_TOKENChanged Macedonia link to Macedo...  2002
# 28         356383  ` NEWLINE_TOKENNEWLINE_TOKEN:Incidentally, re ...  2002
# 29         358984  `I removed ``from scratch``. In addition to yo...  2002
# ...           ...                                                ...   ...
# 115834  699646005   Don't keep changing my page I made please. Yo...  2016
# 115835  699659494  im soory since when is google images not allow...  2016
# 115836  699660419  what ever you fuggin fagNEWLINE_TOKENQuestion ...  2016
# 115837  699661020  NEWLINE_TOKENNEWLINE_TOKEN== Nice try but no c...  2016
# 115838  699661834  `NEWLINE_TOKENNEWLINE_TOKEN== kys ==NEWLINE_TO...  2016
# 115839  699663770  NEWLINE_TOKENNEWLINE_TOKEN== hi Drmies ==NEWLI...  2016
# 115840  699664687   shut up mind your own business and go fuck so...  2016
# 115841  699667660  This talk page is actually a better place to d...  2016
# 115842  699683891  NEWLINE_TOKENNEWLINE_TOKEN== defunct?==NEWLINE...  2016
# 115843  699698850  NEWLINE_TOKENNEWLINE_TOKENYeah, I realized I c...  2016
# 115844  699702006  NEWLINE_TOKEN:There's some weaseling and pov p...  2016
# 115845  699703322  `NEWLINE_TOKEN:::Yeah and in the earlier sente...  2016
# 115846  699715740  `NEWLINE_TOKEN:::::::::::::Again, WP:NOTAFORUM...  2016
# 115847  699728036                      `  [``Those Were the Days``]`  2016
# 115848  699730832  NEWLINE_TOKENNEWLINE_TOKEN== Japanese Scene ==...  2016
# 115849  699732149  NEWLINE_TOKENI am sorry I was only apologizing...  2016
# 115850  699741197  `NEWLINE_TOKENNEWLINE_TOKEN== Jim1138 ==NEWLIN...  2016
# 115851  699753082  NEWLINE_TOKENNEWLINE_TOKEN== Why oh why... ==N...  2016
# 115852  699755057  NEWLINE_TOKENNEWLINE_TOKEN== Daily Beast Artic...  2016
# 115853  699756053  `The lead also lacks proper citation and sourc...  2016
# 115854  699756185  `NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENThe le...  2016
# 115855  699780538          NEWLINE_TOKEN:::::: Well done, thanks!     2016
# 115856  699813325  `NEWLINE_TOKEN::I'm talking about you making u...  2016
# 115857  699820699  `NEWLINE_TOKENYes, from the word ``Guci`` or `...  2016
# 115858  699822249  `NEWLINE_TOKENNEWLINE_TOKEN:``Comment````. Gen...  2016
# 115859  699848324  `NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENThese ...  2016
# 115860  699851288  NEWLINE_TOKENNEWLINE_TOKENThe Institute for Hi...  2016
# 115861  699857133  NEWLINE_TOKEN:The way you're trying to describ...  2016
# 115862  699891012  NEWLINE_TOKENNEWLINE_TOKEN== Warning ==NEWLINE...  2016
# 115863  699897151  Alternate option===NEWLINE_TOKENIs there perha...  2016
#
#         logged_in       ns   sample  split  aggression
# 0            True  article   random  train           0
# 1            True  article   random  train           0
# 2            True  article   random  train           0
# 3            True  article   random    dev           0
# 4            True  article   random  train           0
# 5            True     user   random  train           0
# 6            True  article   random  train           0
# 7            True  article   random    dev           0
# 8            True  article   random    dev           0
# 9           False  article   random  train           0
# 10           True  article   random  train           0
# 11           True  article   random  train           0
# 12           True     user   random   test           0
# 13           True     user   random   test           0
# 14           True  article   random  train           0
# 15           True  article   random    dev           0
# 16           True     user   random  train           0
# 17          False  article   random  train           0
# 18          False  article   random  train           0
# 19           True  article   random  train           0
# 20           True  article   random  train           0
# 21          False  article   random   test           0
# 22           True  article   random    dev           0
# 23          False  article   random  train           0
# 24          False  article   random  train           0
# 25           True  article   random   test           0
# 26           True     user   random    dev           0
# 27           True  article   random  train           0
# 28           True  article   random  train           0
# 29           True  article   random    dev           0
# ...           ...      ...      ...    ...         ...
# 115834       True     user  blocked  train           1
# 115835       True     user  blocked    dev           1
# 115836       True     user  blocked   test           1
# 115837       True     user  blocked  train           1
# 115838       True     user  blocked   test           0
# 115839       True     user  blocked  train           0
# 115840       True     user  blocked    dev           1
# 115841       True  article  blocked  train           0
# 115842       True  article  blocked  train           0
# 115843       True     user  blocked   test           0
# 115844       True  article  blocked  train           0
# 115845       True  article  blocked   test           0
# 115846       True  article  blocked    dev           0
# 115847       True  article   random  train           0
# 115848       True  article  blocked    dev           0
# 115849       True     user   random  train           0
# 115850       True     user  blocked    dev           0
# 115851       True     user  blocked   test           0
# 115852       True  article  blocked    dev           0
# 115853       True  article  blocked    dev           0
# 115854       True  article  blocked  train           0
# 115855       True     user  blocked    dev           0
# 115856       True  article  blocked  train           0
# 115857       True     user  blocked    dev           0
# 115858       True  article  blocked    dev           0
# 115859       True  article  blocked  train           0
# 115860       True  article  blocked   test           0
# 115861       True  article  blocked  train           0
# 115862       True     user  blocked    dev           0
# 115863       True  article  blocked  train           0
#
# [115864 rows x 8 columns]

# %% [markdown]
# #### Remove the NEWLINE_TOKEN and TAB_TOKEN

# %%
df['comment'] = df['comment'].apply(lambda x: x.replace("NEWLINE_TOKEN", " "))
df['comment'] = df['comment'].apply(lambda x: x.replace("TAB_TOKEN", " "))
df['comment'] = df['comment'].apply(lambda x: re.sub(r"((?::|;|=)(?:-)?(?:\)|D|P))", "", x))
df['comment'] = df['comment'].apply(lambda x: re.sub(r"[\"`~=:<>@*-]+", "", x))
df
# Out:
#            rev_id                                            comment  year  \
# 0           37675   This is not creative.  Those are the dictiona...  2002
# 1           44816     the term standard model is itself less NPOV...  2002
# 2           49851    True or false, the situation as of March 200...  2002
# 3           89320   Next, maybe you could work on being less cond...  2002
# 4           93890               This page will need disambiguation.   2002
# 5          102817     Important note for all sysops There is a bu...  2002
# 6          103624  I removed the following  All names of early Po...  2002
# 7          111032  If you ever claimed in a Judaic studies progra...  2002
# 8          120283     My apologies  I'm English, I watch cricket,...  2002
# 9          128532  Someone wrote More recognizable, perhaps, is a...  2002
# 10         133562    Correct. Full biographical details will put ...  2002
# 11         138117    Care should be taken to distinguish when and...  2002
# 12         155243    If I may butt in  I've spent the last 1/4 ho...  2002
# 13         177310     On my  you will find the apology that I owe...  2002
# 14         192579      I fail to see the distinction.  Who better...  2002
# 15         201190                    gets far more tendentious yet.   2002
# 16         208009    As a person who has done some of this activi...  2002
# 17         249432  It's great that we've found a new source of fr...  2001
# 18         252031      No, I really haven't heard of either one, ...  2001
# 19         268558    I'd like the concepts of microevolution and ...  2001
# 20         276906      I agree, the first one is simply wrong, an...  2001
# 21         286174      Yep, that's Twin cities from which this ar...  2002
# 22         290598        That's another relevant empirical questi...  2001
# 23         294124       This sounds right. Historians speak of th...  2002
# 24         297866      Ummm. The article uses imperial measuremen...  2001
# 25         317177                             See? I was right!       2002
# 26         336654    I have checked the licenses, and it is publi...  2002
# 27         344567   Changed Macedonia link to Macedon; ancients d...  2002
# 28         356383     Incidentally, re naming conventions the onl...  2002
# 29         358984  I removed from scratch. In addition to your re...  2002
# ...           ...                                                ...   ...
# 115834  699646005   Don't keep changing my page I made please. Yo...  2016
# 115835  699659494  im soory since when is google images not allow...  2016
# 115836  699660419  what ever you fuggin fag Question how did you ...  2016
# 115837  699661020     Nice try but no cigar........idiot   Then e...  2016
# 115838  699661834     kys   {| stylebackgroundcolor #fdffe7; bord...  2016
# 115839  699663770     hi Drmies   My name's Little Cletus, I'm ju...  2016
# 115840  699664687   shut up mind your own business and go fuck so...  2016
# 115841  699667660  This talk page is actually a better place to d...  2016
# 115842  699683891     defunct? The article sources a claim that W...  2016
# 115843  699698850    Yeah, I realized I created a duplicate ID. S...  2016
# 115844  699702006   There's some weaseling and pov pushing in the...  2016
# 115845  699703322   Yeah and in the earlier sentence I'd reword f...  2016
# 115846  699715740   Again, WPNOTAFORUM (and there's usually a goo...  2016
# 115847  699728036                              [Those Were the Days]  2016
# 115848  699730832     Japanese Scene   The largely neoclassical J...  2016
# 115849  699732149   I am sorry I was only apologizing for if my i...  2016
# 115850  699741197     Jim1138   Hi.  How did you get involved in ...  2016
# 115851  699753082     Why oh why...    You removed the trolls ANI...  2016
# 115852  699755057     Daily Beast Article   I'm removing the sour...  2016
# 115853  699756053  The lead also lacks proper citation and source...  2016
# 115854  699756185     The lead itself is original research. Where...  2016
# 115855  699780538                              Well done, thanks!     2016
# 115856  699813325   I'm talking about you making unjustified majo...  2016
# 115857  699820699   Yes, from the word Guci or Puci meaning flash...  2016
# 115858  699822249    Comment. Gentlemen, this article provides an...  2016
# 115859  699848324     These sources don't exactly exude a sense o...  2016
# 115860  699851288    The Institute for Historical Review is a pee...  2016
# 115861  699857133   The way you're trying to describe it in this ...  2016
# 115862  699891012     Warning   There is clearly a protectionist ...  2016
# 115863  699897151  Alternate option Is there perhaps enough newsw...  2016
#
#         logged_in       ns   sample  split  aggression
# 0            True  article   random  train           0
# 1            True  article   random  train           0
# 2            True  article   random  train           0
# 3            True  article   random    dev           0
# 4            True  article   random  train           0
# 5            True     user   random  train           0
# 6            True  article   random  train           0
# 7            True  article   random    dev           0
# 8            True  article   random    dev           0
# 9           False  article   random  train           0
# 10           True  article   random  train           0
# 11           True  article   random  train           0
# 12           True     user   random   test           0
# 13           True     user   random   test           0
# 14           True  article   random  train           0
# 15           True  article   random    dev           0
# 16           True     user   random  train           0
# 17          False  article   random  train           0
# 18          False  article   random  train           0
# 19           True  article   random  train           0
# 20           True  article   random  train           0
# 21          False  article   random   test           0
# 22           True  article   random    dev           0
# 23          False  article   random  train           0
# 24          False  article   random  train           0
# 25           True  article   random   test           0
# 26           True     user   random    dev           0
# 27           True  article   random  train           0
# 28           True  article   random  train           0
# 29           True  article   random    dev           0
# ...           ...      ...      ...    ...         ...
# 115834       True     user  blocked  train           1
# 115835       True     user  blocked    dev           1
# 115836       True     user  blocked   test           1
# 115837       True     user  blocked  train           1
# 115838       True     user  blocked   test           0
# 115839       True     user  blocked  train           0
# 115840       True     user  blocked    dev           1
# 115841       True  article  blocked  train           0
# 115842       True  article  blocked  train           0
# 115843       True     user  blocked   test           0
# 115844       True  article  blocked  train           0
# 115845       True  article  blocked   test           0
# 115846       True  article  blocked    dev           0
# 115847       True  article   random  train           0
# 115848       True  article  blocked    dev           0
# 115849       True     user   random  train           0
# 115850       True     user  blocked    dev           0
# 115851       True     user  blocked   test           0
# 115852       True  article  blocked    dev           0
# 115853       True  article  blocked    dev           0
# 115854       True  article  blocked  train           0
# 115855       True     user  blocked    dev           0
# 115856       True  article  blocked  train           0
# 115857       True     user  blocked    dev           0
# 115858       True  article  blocked    dev           0
# 115859       True  article  blocked  train           0
# 115860       True  article  blocked   test           0
# 115861       True  article  blocked  train           0
# 115862       True     user  blocked    dev           0
# 115863       True  article  blocked  train           0
#
# [115864 rows x 8 columns]

# %% [markdown]
# Rename the comment column

# %%
df = df.rename(columns={'rev_id': 'rev_id', 'comment': 'text', 'year': 'year', 'logged_in': 'logged_in', 'ns': 'ns', 'sample': 'sample', 'split': 'split', 'aggression': 'aggression'})
df
# Out:
#            rev_id                                               text  year  \
# 0           37675   This is not creative.  Those are the dictiona...  2002
# 1           44816     the term standard model is itself less NPOV...  2002
# 2           49851    True or false, the situation as of March 200...  2002
# 3           89320   Next, maybe you could work on being less cond...  2002
# 4           93890               This page will need disambiguation.   2002
# 5          102817     Important note for all sysops There is a bu...  2002
# 6          103624  I removed the following  All names of early Po...  2002
# 7          111032  If you ever claimed in a Judaic studies progra...  2002
# 8          120283     My apologies  I'm English, I watch cricket,...  2002
# 9          128532  Someone wrote More recognizable, perhaps, is a...  2002
# 10         133562    Correct. Full biographical details will put ...  2002
# 11         138117    Care should be taken to distinguish when and...  2002
# 12         155243    If I may butt in  I've spent the last 1/4 ho...  2002
# 13         177310     On my  you will find the apology that I owe...  2002
# 14         192579      I fail to see the distinction.  Who better...  2002
# 15         201190                    gets far more tendentious yet.   2002
# 16         208009    As a person who has done some of this activi...  2002
# 17         249432  It's great that we've found a new source of fr...  2001
# 18         252031      No, I really haven't heard of either one, ...  2001
# 19         268558    I'd like the concepts of microevolution and ...  2001
# 20         276906      I agree, the first one is simply wrong, an...  2001
# 21         286174      Yep, that's Twin cities from which this ar...  2002
# 22         290598        That's another relevant empirical questi...  2001
# 23         294124       This sounds right. Historians speak of th...  2002
# 24         297866      Ummm. The article uses imperial measuremen...  2001
# 25         317177                             See? I was right!       2002
# 26         336654    I have checked the licenses, and it is publi...  2002
# 27         344567   Changed Macedonia link to Macedon; ancients d...  2002
# 28         356383     Incidentally, re naming conventions the onl...  2002
# 29         358984  I removed from scratch. In addition to your re...  2002
# ...           ...                                                ...   ...
# 115834  699646005   Don't keep changing my page I made please. Yo...  2016
# 115835  699659494  im soory since when is google images not allow...  2016
# 115836  699660419  what ever you fuggin fag Question how did you ...  2016
# 115837  699661020     Nice try but no cigar........idiot   Then e...  2016
# 115838  699661834     kys   {| stylebackgroundcolor #fdffe7; bord...  2016
# 115839  699663770     hi Drmies   My name's Little Cletus, I'm ju...  2016
# 115840  699664687   shut up mind your own business and go fuck so...  2016
# 115841  699667660  This talk page is actually a better place to d...  2016
# 115842  699683891     defunct? The article sources a claim that W...  2016
# 115843  699698850    Yeah, I realized I created a duplicate ID. S...  2016
# 115844  699702006   There's some weaseling and pov pushing in the...  2016
# 115845  699703322   Yeah and in the earlier sentence I'd reword f...  2016
# 115846  699715740   Again, WPNOTAFORUM (and there's usually a goo...  2016
# 115847  699728036                              [Those Were the Days]  2016
# 115848  699730832     Japanese Scene   The largely neoclassical J...  2016
# 115849  699732149   I am sorry I was only apologizing for if my i...  2016
# 115850  699741197     Jim1138   Hi.  How did you get involved in ...  2016
# 115851  699753082     Why oh why...    You removed the trolls ANI...  2016
# 115852  699755057     Daily Beast Article   I'm removing the sour...  2016
# 115853  699756053  The lead also lacks proper citation and source...  2016
# 115854  699756185     The lead itself is original research. Where...  2016
# 115855  699780538                              Well done, thanks!     2016
# 115856  699813325   I'm talking about you making unjustified majo...  2016
# 115857  699820699   Yes, from the word Guci or Puci meaning flash...  2016
# 115858  699822249    Comment. Gentlemen, this article provides an...  2016
# 115859  699848324     These sources don't exactly exude a sense o...  2016
# 115860  699851288    The Institute for Historical Review is a pee...  2016
# 115861  699857133   The way you're trying to describe it in this ...  2016
# 115862  699891012     Warning   There is clearly a protectionist ...  2016
# 115863  699897151  Alternate option Is there perhaps enough newsw...  2016
#
#         logged_in       ns   sample  split  aggression
# 0            True  article   random  train           0
# 1            True  article   random  train           0
# 2            True  article   random  train           0
# 3            True  article   random    dev           0
# 4            True  article   random  train           0
# 5            True     user   random  train           0
# 6            True  article   random  train           0
# 7            True  article   random    dev           0
# 8            True  article   random    dev           0
# 9           False  article   random  train           0
# 10           True  article   random  train           0
# 11           True  article   random  train           0
# 12           True     user   random   test           0
# 13           True     user   random   test           0
# 14           True  article   random  train           0
# 15           True  article   random    dev           0
# 16           True     user   random  train           0
# 17          False  article   random  train           0
# 18          False  article   random  train           0
# 19           True  article   random  train           0
# 20           True  article   random  train           0
# 21          False  article   random   test           0
# 22           True  article   random    dev           0
# 23          False  article   random  train           0
# 24          False  article   random  train           0
# 25           True  article   random   test           0
# 26           True     user   random    dev           0
# 27           True  article   random  train           0
# 28           True  article   random  train           0
# 29           True  article   random    dev           0
# ...           ...      ...      ...    ...         ...
# 115834       True     user  blocked  train           1
# 115835       True     user  blocked    dev           1
# 115836       True     user  blocked   test           1
# 115837       True     user  blocked  train           1
# 115838       True     user  blocked   test           0
# 115839       True     user  blocked  train           0
# 115840       True     user  blocked    dev           1
# 115841       True  article  blocked  train           0
# 115842       True  article  blocked  train           0
# 115843       True     user  blocked   test           0
# 115844       True  article  blocked  train           0
# 115845       True  article  blocked   test           0
# 115846       True  article  blocked    dev           0
# 115847       True  article   random  train           0
# 115848       True  article  blocked    dev           0
# 115849       True     user   random  train           0
# 115850       True     user  blocked    dev           0
# 115851       True     user  blocked   test           0
# 115852       True  article  blocked    dev           0
# 115853       True  article  blocked    dev           0
# 115854       True  article  blocked  train           0
# 115855       True     user  blocked    dev           0
# 115856       True  article  blocked  train           0
# 115857       True     user  blocked    dev           0
# 115858       True  article  blocked    dev           0
# 115859       True  article  blocked  train           0
# 115860       True  article  blocked   test           0
# 115861       True  article  blocked  train           0
# 115862       True     user  blocked    dev           0
# 115863       True  article  blocked  train           0
#
# [115864 rows x 8 columns]

# %%
df.to_csv("./data/cleaned_data.csv", index=False)

# %%
df.groupby('aggression').agg('count')
# Out:
#             rev_id    text    year  logged_in      ns  sample   split
# aggression
# 0           101082  101082  101082     101082  101082  101082  101082
# 1            14782   14782   14782      14782   14782   14782   14782
